# %% [markdown]
# <a href="https://colab.research.google.com/github/LakshminandaKP/machine-learning/blob/main/DECISION_TREE_(Iris).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DECISION TREE**

# %% [markdown]
# ## IMPORT MODULES

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## DATASET

# %%
iris=load_iris()
iris
X,Y=iris.data,iris.target

# %% [markdown]
# ## SPLITTING THE DATASET

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,random_state=50,test_size=0.2)

# %% [markdown]
# ## FITTING

# %%
m=DecisionTreeClassifier(criterion='entropy',random_state=50)
m.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=50)

# %% [markdown]
# ## PREDICTING

# %%
Y_pred=m.predict(X_test)

# %% [markdown]
# ## EVALUATION

# %%
accuracy=accuracy_score(Y_test,Y_pred)
accuracy
# Out:
# 0.9666666666666667

# %% [markdown]
# ## VISUALIZE

# %%
plt.figure(figsize=(13,9))

plot_tree(m,filled=True,feature_names=iris.feature_names,class_names=iris.target_names)
plt.show()
